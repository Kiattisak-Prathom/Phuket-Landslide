# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiattisak-Prathom/Phuket-Landslide/blob/main/Relation_of_data_Phuket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("Nolandslidepointwith12Factors.xls")
df2 = pd.read_excel("landslidepointwith12Factors.xls")

# %%
dfR=pd.concat([df1,df2],axis=0,ignore_index=True)

# %%
dfR.isna().sum()
# Out:
# x                     0
# y                     0
# mosaic_phuket_Clip    1
# Slope_mosaic1         1
# Aspect_mosai1         1
# Curvatu_mosa1         1
# ndvi_phuket_Clip      1
# ndwi_phuket           1
# Distance_to_Fault     1
# Distance_to_roads     1
# Distance_to_Rivers    1
# Kriging_rain1         1
# TWI_phuket            0
# DMR_Geology           2
# yi                    0
# dtype: int64

# %%
dfR1=dfR.dropna()
dfR1=dfR1.reset_index(drop=True)

# %%
dfR1
# Out:
#                x            y  mosaic_phuket_Clip  Slope_mosaic1  \
# 0    423660.4427  903348.7826                17.0       2.510501
# 1    423363.3493  904982.7961                 8.0       0.466477
# 2    422249.2492  903497.3293                13.0       1.189142
# 3    424997.3628  902606.0492                36.0       4.712167
# 4    423140.5293  900229.3024                16.0       1.648825
# ..           ...          ...                 ...            ...
# 275  432633.0000  863208.0000                32.0      21.049906
# 276  432563.0000  863217.0000                48.0      16.552008
# 277  431034.0000  861296.0000                81.0      32.634781
# 278  423754.0000  861833.0000                66.0      15.678538
# 279  429844.0000  856089.0000                38.0      43.720284
#
#      Aspect_mosai1  Curvatu_mosa1  ndvi_phuket_Clip  ndwi_phuket  \
# 0        68.198593      -0.212121          0.369317    -0.348617
# ...

# %%
dfR2 = pd.read_excel("Phuket_landslide_normalized_finaldata.xlsx")

# %%
dfR2
# Out:
#      Unnamed: 0            x            y  mosaic_phuket_Clip  Slope_mosaic1  \
# 0             0  423660.4427  903348.7826            0.034261       0.056438
# 1             1  423363.3493  904982.7961            0.014989       0.010487
# 2             2  422249.2492  903497.3293            0.025696       0.026733
# 3             3  424997.3628  902606.0492            0.074946       0.105933
# 4             4  423140.5293  900229.3024            0.032120       0.037067
# ..          ...          ...          ...                 ...            ...
# 275         275  432633.0000  863208.0000            0.066381       0.473217
# 276         276  432563.0000  863217.0000            0.100642       0.372101
# 277         277  431034.0000  861296.0000            0.171306       0.733653
# 278         278  423754.0000  861833.0000            0.139186       0.352465
# 279         279  429844.0000  856089.0000            0.079229       0.982863
#
# ...

# %%
dfR2 = dfR2.drop(columns =['Unnamed: 0']).astype(float)

# %%
dfR2
# Out:
#                x            y  mosaic_phuket_Clip  Slope_mosaic1  \
# 0    423660.4427  903348.7826            0.034261       0.056438
# 1    423363.3493  904982.7961            0.014989       0.010487
# 2    422249.2492  903497.3293            0.025696       0.026733
# 3    424997.3628  902606.0492            0.074946       0.105933
# 4    423140.5293  900229.3024            0.032120       0.037067
# ..           ...          ...                 ...            ...
# 275  432633.0000  863208.0000            0.066381       0.473217
# 276  432563.0000  863217.0000            0.100642       0.372101
# 277  431034.0000  861296.0000            0.171306       0.733653
# 278  423754.0000  861833.0000            0.139186       0.352465
# 279  429844.0000  856089.0000            0.079229       0.982863
#
#      Aspect_mosai1  Curvatu_mosa1  ndvi_phuket_Clip  ndwi_phuket  \
# 0         0.193898       0.551020          0.736907     0.245548
# ...

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="mosaic_phuket_Clip", hue="yi", palette=["blue", "red"], multiple="stack",bins=100)
# Customize the plot (optional)
plt.xlabel("Feature 1")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.show()

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="mosaic_phuket_Clip", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 1: Elevation")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F1.svg', format='svg')

# %%
plt.savefig('mosaic_phuket_Clip.png')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Slope_mosaic1", hue="yi", palette=["blue", "red"],bins=100,kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 2: Slope angle")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F2.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Aspect_mosai1", hue="yi", palette=["blue", "red"],bins=100,kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 3: Aspect")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper center")
# Display the plot
plt.plot()
plt.savefig('F3.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Curvatu_mosa1", hue="yi", palette=["blue", "red"],bins=100,kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 4: Curvature")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F4.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="ndvi_phuket_Clip", hue="yi", palette=["blue", "red"],bins=100,kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 5: NDVI")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper center")
# Display the plot
plt.plot()
plt.savefig('F5.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="ndwi_phuket", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 6: NDWI")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F6.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Distance_to_Fault", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 7: Distance to faults")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F7.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Distance_to_roads", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 8: Distance to roads")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F8.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Distance_to_Rivers", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 9: Distance to rivers")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F9.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="Kriging_rain1", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 10: Rainfall intensity")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F10.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="TWI_phuket", hue="yi", palette=["blue", "red"],bins=100, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 11: TWI")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F11.svg', format='svg')

# %%
plt.figure(figsize=(5, 3))  # Adjust figure size as needed
sns.histplot(data=dfR1, x="DMR_Geology", hue="yi", palette=["blue", "red"],bins=20, kde=True)

# Customize the plot (optional)
plt.xlabel("Feature 12: Lithology")
plt.ylabel("Frequency")
plt.legend(['landslide', 'non-landslide'], loc="upper right")
# Display the plot
plt.plot()
plt.savefig('F12.svg', format='svg')

# %%
plt.scatter(dfR1[dfR1['yi'] == 1]['mosaic_phuket_Clip'], dfR1[dfR1['yi'] == 1]['Curvatu_mosa1'], color = 'red')
plt.scatter(dfR1[dfR1['yi'] != 1]['mosaic_phuket_Clip'], dfR1[dfR1['yi'] != 1]['Curvatu_mosa1'], color = 'blue')
plt.show()

# %%
plt.scatter(dfR2[dfR2['yi'] == 1]['mosaic_phuket_Clip'], [1] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['mosaic_phuket_Clip'], [1] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Slope_mosaic1'], [2] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Slope_mosaic1'], [2] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Aspect_mosai1'], [3] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Aspect_mosai1'], [3] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Curvatu_mosa1'], [4] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Curvatu_mosa1'], [4] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['ndvi_phuket_Clip'], [5] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['ndvi_phuket_Clip'], [5] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['ndwi_phuket'], [6] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['ndwi_phuket'], [6] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Distance_to_Fault'], [7] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Distance_to_Fault'], [7] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Distance_to_roads'], [8] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Distance_to_roads'], [8] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Distance_to_Rivers'], [9] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Distance_to_Rivers'], [9] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['Kriging_rain1'], [10] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['Kriging_rain1'], [10] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['TWI_phuket'], [11] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['TWI_phuket'], [11] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.scatter(dfR2[dfR2['yi'] == 1]['DMR_Geology'], [12] * len(dfR2[dfR2['yi'] == 1]), color = 'red')
plt.scatter(dfR2[dfR2['yi'] != 1]['DMR_Geology'], [12] * len(dfR2[dfR2['yi'] != 1]), color = 'blue',facecolors='none')
plt.legend(['landslide', 'non-lanslide'], loc="upper right", bbox_to_anchor=(1.3, 1))
plt.yticks(np.arange(1,13,1))
plt.xlabel("Normalized values")
plt.ylabel("Feature indices")
plt.show()

# %%
plt.scatter(dfR1[dfR1['yi'] == 1]['Slope_mosaic1'], dfR1[dfR1['yi'] == 1]['Slope_mosaic1'], color = 'red')
plt.scatter(dfR1[dfR1['yi'] != 1]['Slope_mosaic1'], dfR1[dfR1['yi'] != 1]['Slope_mosaic1'], color = 'blue')
plt.show()

# %%
plt.scatter(dfR1[dfR1['yi'] == 1]['yi'], dfR1[dfR1['yi'] == 0]['yi'], color = 'blue')

plt.scatter(dfR1[dfR1['Month'] != 'January']['Open'], djia_data[djia_data['Month'] != 'January']['Close'], color = 'gray')

plt.show()

# %%
val = 0. # this is the value where you want the data to appear on the y-axis.
ar = np.arange(10) # just as an example array
plt.plot(ar, np.zeros_like(ar) + val, 'x')
plt.show()

# %%
X = np.arange(len(dfR1))

plt.scatter( [1] * np.arange(len(dfR1)).shape[0], np.arange(len(dfR1)))
